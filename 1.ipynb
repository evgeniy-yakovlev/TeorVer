# %%
import scipy.special as sc

# %% [markdown]
# #Решение задач по теорверу 1 тема: **комбинаторика**

# %% [markdown]
# ##Решил использовать scipy, так как он должен быть производительнее

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# а) Здесь используем формулу размещений с повторениями

# %%
10**5
# Out:
# 100000

# %% [markdown]
# б) Здесь используем формулу сочетаний с повторениями

# %%
sc.comb(10, 5, exact=True, repetition=True)
# Out:
# 2002

# %% [markdown]
# Еще можно явно использовать формулу:

# %%
sc.comb(10 + 5 - 1, 5)
# Out:
# np.float64(2002.0)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %%
sc.factorial(7) / sc.factorial(3) / sc.factorial(2) / sc.factorial(2)
# Out:
# np.float64(210.0)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %%
# a
alph = 'теория'
k = len(set(alph))

print(round(1 / sc.perm(6, 3), 4))

# b
print(round(1 / sc.factorial(6), 4))
# Out:
# 0.0083
# 0.0014

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# Здесь отличие в том, что используются перестановки с повторениями (3,2,1)

# %%
all = sc.factorial(6) / sc.factorial(3) / sc.factorial(2)

round(1 / all, 4)
# Out:
# np.float64(0.0167)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %%
round(2 * sc.factorial(5) ** 2 / sc.factorial(10), 4)
# Out:
# np.float64(0.0079)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# В учебнике возможно ошибка, так как там в числитиле не умножено еще раз на 2. Число благоприятных случаев: 2 способа выбрать пары на круге, в каждой паре муж и жена могут меняться местами, всего способов разместить 5 мужчин это 5!

# %%
round(2**6 * sc.factorial(5) / sc.factorial(10), 4)
# Out:
# np.float64(0.0021)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %%
# a
round(sc.comb(9, 2) * sc.comb(8, 7) / sc.comb(36, 7), 7)
# Out:
# np.float64(3.45e-05)

# %%
# b
round(sc.comb(9, 7) * 4**7 / sc.comb(36, 7), 4)
# Out:
# np.float64(0.0707)

# %% [markdown]
# Здесь учитываем случай, когда из 3 выбранных купе все 7 попадут в 2 купе (а по условию все 3 должны быть заняты). Из общего числа возможностей выбрать 7 мест из 12 вычитаем число комбинаций по 2 из 3 купе, когда из 8 мест в этих 2 купе выбраны 7

# %%
# c
round(sc.comb(9, 3) * (sc.comb(12, 7) - sc.comb(3, 2) * sc.comb(8, 7)) / sc.comb(36, 7), 4)
# Out:
# np.float64(0.0077)
